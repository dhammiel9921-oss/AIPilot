# %% [markdown]
# # Milestone C: Prototype Implementation Template
#
# ## [Your Project Title Here]
#
# **Student Name:** [Your Name]
#
# **Date:** [Date]
#
# ---
#
# ## Notebook Purpose
#
# This notebook contains your working prototype. By the end of this milestone, you should have:
#
# 1. ✅ Complete preprocessing pipeline from Milestone B
# 2. ✅ Model architecture implemented
# 3. ✅ Training loop executed with logging
# 4. ✅ Training/validation curves visualized
# 5. ✅ Initial evaluation on test set
# 6. ✅ Sample predictions displayed
#
# **Important:** Your prototype should run without errors and demonstrate a working pipeline, even if performance is not yet optimized.

# %% [markdown]
# ---
# ## 1. Environment Setup and Data Loading
#
# Import your code from Milestone B and load the data.

# %%
# ==============================================================================
# IMPORTS
# ==============================================================================
# TODO: Copy your imports from Milestone B and add any new ones needed
#
# Additional imports you may need for Milestone C:
# - Model layers and architectures
# - Callbacks (EarlyStopping, ModelCheckpoint, etc.)
# - Evaluation metrics
# - Visualization utilities

# Your imports here:


# Set random seeds for reproducibility
# np.random.seed(42)
# tf.random.set_seed(42)

# %%
# ==============================================================================
# LOAD DATA (from Milestone B)
# ==============================================================================
# TODO: Copy your data loading code from Milestone B
# Include:
# - Data paths
# - Data generators/loaders
# - Class weights (if applicable)

# Your data loading code here:

# %%
# ==============================================================================
# VERIFY DATA LOADING
# ==============================================================================
# TODO: Print summary to confirm data is loaded correctly
#
# print(f"Training samples: {train_generator.samples}")
# print(f"Validation samples: {val_generator.samples}")
# print(f"Test samples: {test_generator.samples}")
# print(f"Class indices: {train_generator.class_indices}")

# Your verification code here:

# %% [markdown]
# ---
# ## 2. Model Architecture
#
# Build your model according to the design document from Milestone B.

# %%
# ==============================================================================
# BUILD MODEL FUNCTION
# ==============================================================================
# TODO: Define a function to build your model
# This makes it easy to rebuild the model if needed
#
# def build_model():
#     """
#     Build and return the model architecture.
#     
#     Returns:
#         model: Compiled Keras model
#     """
#     # Load base model (for transfer learning)
#     # base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
#     # base_model.trainable = False  # Freeze initially
#     
#     # Build model
#     # model = tf.keras.Sequential([
#     #     base_model,
#     #     # Add your layers here
#     # ])
#     
#     return model

# Your model building function here:

# %%
# ==============================================================================
# CREATE MODEL
# ==============================================================================
# TODO: Build your model and display summary
#
# model = build_model()
# model.summary()

# Your code here:

# %%
# ==============================================================================
# COUNT PARAMETERS
# ==============================================================================
# TODO: Display trainable vs non-trainable parameter counts
# This is important for understanding your model's complexity
#
# trainable_count = np.sum([K.count_params(w) for w in model.trainable_weights])
# non_trainable_count = np.sum([K.count_params(w) for w in model.non_trainable_weights])
# print(f"Trainable parameters: {trainable_count:,}")
# print(f"Non-trainable parameters: {non_trainable_count:,}")

# Your code here:

# %% [markdown]
# ---
# ## 3. Training Configuration
#
# Set up optimizers, loss functions, and callbacks.

# %%
# ==============================================================================
# COMPILE MODEL
# ==============================================================================
# TODO: Compile your model with appropriate settings
#
# model.compile(
#     optimizer=Adam(learning_rate=1e-4),        # Your optimizer
#     loss='binary_crossentropy',                 # Your loss function
#     metrics=['accuracy']                        # Your metrics
# )
#
# print("Model compiled successfully!")

# Your compilation code here:

# %%
# ==============================================================================
# DEFINE CALLBACKS
# ==============================================================================
# TODO: Set up training callbacks
# Common callbacks:
#
# 1. Early Stopping - prevents overfitting
# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=5,               # Stop after 5 epochs with no improvement
#     restore_best_weights=True # Restore weights from best epoch
# )
#
# 2. Learning Rate Reduction - helps fine-tune
# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,               # Reduce LR by half
#     patience=3,               # After 3 epochs with no improvement
#     min_lr=1e-7
# )
#
# 3. Model Checkpoint - save best model
# checkpoint = ModelCheckpoint(
#     'best_model.keras',
#     monitor='val_loss',
#     save_best_only=True
# )
#
# callbacks = [early_stopping, reduce_lr, checkpoint]

# Your callbacks here:

# %% [markdown]
# ---
# ## 4. Model Training
#
# Train your model. Consider using a two-phase approach if doing transfer learning:
# - **Phase 1:** Train only the new layers (base frozen)
# - **Phase 2:** Fine-tune some base layers (optional)

# %%
# ==============================================================================
# TRAINING CONFIGURATION
# ==============================================================================
# TODO: Define training parameters

# EPOCHS = 20                # Number of training epochs
# INITIAL_EPOCHS = 10        # Epochs for Phase 1 (if using two-phase)
# FINE_TUNE_EPOCHS = 10      # Additional epochs for Phase 2

# Your configuration here:

# %%
# ==============================================================================
# PHASE 1: INITIAL TRAINING (or single-phase training)
# ==============================================================================
# TODO: Train your model
#
# print("Starting training...")
#
# history = model.fit(
#     train_generator,
#     epochs=EPOCHS,
#     validation_data=validation_generator,
#     class_weight=class_weights,    # If handling imbalance
#     callbacks=callbacks,
#     verbose=1
# )
#
# print("Training complete!")

# Your training code here:

# %%
# ==============================================================================
# PHASE 2: FINE-TUNING (OPTIONAL - for transfer learning)
# ==============================================================================
# TODO: If using transfer learning, optionally fine-tune some base layers
#
# Steps:
# 1. Unfreeze some layers:
#    base_model.trainable = True
#    for layer in base_model.layers[:-N]:  # Keep first layers frozen
#        layer.trainable = False
#
# 2. Recompile with lower learning rate:
#    model.compile(
#        optimizer=Adam(learning_rate=1e-5),  # Much lower!
#        loss='binary_crossentropy',
#        metrics=['accuracy']
#    )
#
# 3. Continue training:
#    history_fine = model.fit(...)

# Your fine-tuning code here (if applicable):

# %% [markdown]
# ---
# ## 5. Training Visualization
#
# Visualize the training process to understand model behavior.

# %%
# ==============================================================================
# PLOT LEARNING CURVES
# ==============================================================================
# TODO: Plot training and validation loss/accuracy curves
#
# def plot_training_history(history):
#     """
#     Plot training and validation metrics over epochs.
#     """
#     fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#     
#     # Loss plot
#     axes[0].plot(history.history['loss'], label='Training Loss')
#     axes[0].plot(history.history['val_loss'], label='Validation Loss')
#     axes[0].set_title('Loss Curves')
#     axes[0].set_xlabel('Epoch')
#     axes[0].set_ylabel('Loss')
#     axes[0].legend()
#     
#     # Accuracy plot
#     axes[1].plot(history.history['accuracy'], label='Training Accuracy')
#     axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
#     axes[1].set_title('Accuracy Curves')
#     axes[1].set_xlabel('Epoch')
#     axes[1].set_ylabel('Accuracy')
#     axes[1].legend()
#     
#     plt.tight_layout()
#     plt.show()
#
# plot_training_history(history)

# Your visualization code here:

# %%
# ==============================================================================
# ANALYZE TRAINING BEHAVIOR
# ==============================================================================
# TODO: Analyze the learning curves
# Questions to answer:
# - Is the model converging?
# - Is there evidence of overfitting (train loss << val loss)?
# - Is there evidence of underfitting (both losses high)?
# - Was early stopping triggered? At which epoch?

# Print key statistics:
# final_train_loss = history.history['loss'][-1]
# final_val_loss = history.history['val_loss'][-1]
# final_train_acc = history.history['accuracy'][-1]
# final_val_acc = history.history['val_accuracy'][-1]
#
# print(f"Final Training Loss: {final_train_loss:.4f}")
# print(f"Final Validation Loss: {final_val_loss:.4f}")
# print(f"Final Training Accuracy: {final_train_acc:.4f}")
# print(f"Final Validation Accuracy: {final_val_acc:.4f}")

# Your analysis here:

# %% [markdown]
# ---
# ## 6. Model Evaluation
#
# Evaluate your model on the test set.

# %%
# ==============================================================================
# LOAD BEST MODEL (if using checkpoint)
# ==============================================================================
# TODO: Load the best model from checkpoint
#
# model = keras.models.load_model('best_model.keras')
# print("Loaded best model from checkpoint")

# Your code here:

# %%
# ==============================================================================
# EVALUATE ON TEST SET
# ==============================================================================
# TODO: Get overall test metrics
#
# test_loss, test_acc = model.evaluate(test_generator)
# print(f"Test Loss: {test_loss:.4f}")
# print(f"Test Accuracy: {test_acc:.4f}")

# Your evaluation code here:

# %%
# ==============================================================================
# GET PREDICTIONS
# ==============================================================================
# TODO: Get predictions for detailed analysis
#
# test_generator.reset()
# y_pred_proba = model.predict(test_generator)
# y_pred = (y_pred_proba > 0.5).astype(int).flatten()  # For binary
# y_true = test_generator.classes

# Your prediction code here:

# %%
# ==============================================================================
# CLASSIFICATION REPORT
# ==============================================================================
# TODO: Print detailed classification metrics
#
# from sklearn.metrics import classification_report
# print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))

# Your code here:

# %%
# ==============================================================================
# CONFUSION MATRIX
# ==============================================================================
# TODO: Create and visualize confusion matrix
#
# from sklearn.metrics import confusion_matrix
# import seaborn as sns
#
# cm = confusion_matrix(y_true, y_pred)
#
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
#             xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.show()

# Your visualization code here:

# %%
# ==============================================================================
# ROC CURVE (for binary classification)
# ==============================================================================
# TODO: Plot ROC curve and calculate AUC
#
# from sklearn.metrics import roc_curve, auc
#
# fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
# roc_auc = auc(fpr, tpr)
#
# plt.figure(figsize=(8, 6))
# plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.4f})')
# plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()

# Your ROC curve code here:

# %% [markdown]
# ---
# ## 7. Sample Predictions
#
# Visualize predictions on sample test images.

# %%
# ==============================================================================
# VISUALIZE SAMPLE PREDICTIONS
# ==============================================================================
# TODO: Display sample predictions with confidence scores
#
# def visualize_predictions(generator, model, num_samples=10):
#     """
#     Display sample predictions with confidence scores.
#     Color-code: green=correct, red=incorrect
#     """
#     generator.reset()
#     batch = next(generator)
#     images, labels = batch
#     predictions = model.predict(images)
#     
#     fig, axes = plt.subplots(2, 5, figsize=(15, 6))
#     axes = axes.flatten()
#     
#     for i, ax in enumerate(axes[:num_samples]):
#         ax.imshow(images[i])
#         true_label = CLASS_NAMES[int(labels[i])]
#         pred_label = CLASS_NAMES[int(predictions[i] > 0.5)]
#         confidence = predictions[i][0] if predictions[i] > 0.5 else 1 - predictions[i][0]
#         
#         color = 'green' if true_label == pred_label else 'red'
#         ax.set_title(f'True: {true_label}\nPred: {pred_label} ({confidence:.1%})', color=color)
#         ax.axis('off')
#     
#     plt.tight_layout()
#     plt.show()
#
# visualize_predictions(test_generator, model)

# Your visualization code here:

# %%
# ==============================================================================
# ANALYZE MISCLASSIFICATIONS (Optional but recommended)
# ==============================================================================
# TODO: Look at examples of incorrect predictions
# This helps understand model weaknesses
#
# Questions to consider:
# - Are there patterns in misclassified samples?
# - Are certain classes more often confused?
# - Are misclassifications low-confidence or high-confidence?

# Your analysis code here:

# %% [markdown]
# ---
# ## 8. Model Interpretability (Optional)
#
# Implement visualization techniques to understand model decisions (e.g., Grad-CAM for images).

# %%
# ==============================================================================
# GRAD-CAM VISUALIZATION (for CNNs - optional)
# ==============================================================================
# TODO: Implement Grad-CAM to visualize model attention
#
# Grad-CAM highlights which image regions influenced the prediction.
# This is useful for:
# - Verifying model focuses on relevant features
# - Building trust in model decisions
# - Debugging unexpected predictions
#
# Basic steps:
# 1. Get output of last convolutional layer
# 2. Compute gradient of prediction w.r.t. that output
# 3. Weight feature maps by gradient importance
# 4. Create heatmap and overlay on original image

# Your Grad-CAM code here (if implementing):

# %% [markdown]
# ---
# ## 9. Save Model
#
# Save your trained model for future use.

# %%
# ==============================================================================
# SAVE FINAL MODEL
# ==============================================================================
# TODO: Save your trained model
#
# model.save('final_model.keras')
# print("Model saved successfully!")

# Your code here:

# %% [markdown]
# ---
# ## 10. Results Summary
#
# Summarize your prototype results.

# %%
# ==============================================================================
# RESULTS SUMMARY TABLE
# ==============================================================================
# TODO: Create a summary of your results
#
# results = {
#     'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC-ROC'],
#     'Value': [accuracy, precision, recall, f1, auc_score]
# }
# results_df = pd.DataFrame(results)
# display(results_df)

# Your summary table here:

# %%
# ==============================================================================
# SUCCESS CRITERIA CHECK
# ==============================================================================
# TODO: Check if you met your success criteria from Milestone B
#
# criteria = [
#     ('Accuracy >= 90%', accuracy >= 0.90),
#     ('Recall >= 85%', recall >= 0.85),
#     # Add your other criteria
# ]
#
# for name, passed in criteria:
#     status = '✓ PASS' if passed else '✗ FAIL'
#     print(f"{status}: {name}")

# Your criteria check here:

# %% [markdown]
# ---
# ## 11. Challenges and Next Steps
#
# Document challenges encountered and plans for improvement.

# %% [markdown]
# ### Challenges Encountered
#
# **TODO:** Document the challenges you faced during implementation:
#
# 1. **Challenge 1:** [Description]
#    - *Impact:* [How did it affect progress?]
#    - *Solution:* [How did you address it?]
#
# 2. **Challenge 2:** [Description]
#    - *Impact:* [How did it affect progress?]
#    - *Solution:* [How did you address it?]
#
# ### Lessons Learned
#
# - [Lesson 1]
# - [Lesson 2]
#
# ### Next Steps for Final Report (Milestone E)
#
# - [ ] [Improvement 1]
# - [ ] [Improvement 2]
# - [ ] [Additional analysis]
# - [ ] [Literature review expansion]

# %% [markdown]
# ---
# ## Summary
#
# ### Prototype Status
#
# - [ ] Model trains without errors
# - [ ] Training curves show convergence
# - [ ] Initial evaluation completed
# - [ ] Sample predictions visualized
# - [ ] Results meet minimum expectations
#
# ### Key Results
#
# | Metric | Value |
# |--------|-------|
# | Test Accuracy | [TODO] |
# | Precision | [TODO] |
# | Recall | [TODO] |
# | F1 Score | [TODO] |
# | AUC-ROC | [TODO] |
#
# ### Changes from Milestone B Design
#
# - [TODO: Document any changes you made from your original design and why]
#
# ---
# *Notebook completed for Milestone C*
